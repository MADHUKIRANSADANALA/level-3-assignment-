# %% [markdown]
# ### matplotlib notebook

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.figure()
plt.subplot(1,2,2)
linear_data=np.array([1,2,3,4,5,6,7,8])
plt.plot(linear_data,'-o')

# %%
left=np.array([1,3,5])
right=np.array([2,4,6])
plt.figure()
plt.subplot(2,2,1)
plt.plot(left,'-o')
plt.subplot(2,2,2)
plt.plot(right,'-o')
plt.subplot(2,2,3)
plt.plot(np.array([10,11]),'-o')

# %%
plt.figure()
ax1=plt.subplot(1,2,1)
plt.plot([1,2,3],np.array([50,60,70]),'-0')
ax2=plt.subplot(1,2,2,sharey=ax1)
plt.plot([1,2,3],np.array([50,30,40]),'-x')

# %%
fig,((ax1,ax2,ax3),(ax4,ax5,ax6),(ax7,ax8,ax9))=plt.subplots(3,3,sharex=True,sharey=True)
ax5.plot(linear_data,'-')

# %%
plt.figure()
linear_data=np.array([10,20,30,40,10,10])
xvals= range(len(linear_data))
plt.bar(xvals,linear_data,width=0.3)
# Out:
# <BarContainer object of 6 artists>

# %%
plt.figure()
linear_data=np.array([10,20,30,40])
xvals=range(len(linear_data))
plt.barh(xvals,linear_data,hieght=0.3)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-cd153d38de03> in <module>
#       2 linear_data=np.array([10,20,30,40])
#       3 xvals=range(len(linear_data))
# ----> 4 plt.barh(xvals,linear_data,hieght=0.3)
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in barh(y, width, height, left, align, **kwargs)
#    2469 def barh(y, width, height=0.8, left=None, *, align='center', **kwargs):
#    2470     return gca().barh(
# -> 2471         y, width, height=height, left=left, align=align, **kwargs)
#    2472
#    2473
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in barh(self, y, width, height, left, align, **kwargs)
#    2461         kwargs.setdefault('orientation', 'horizontal')
#    2462         patches = self.bar(x=left, height=height, width=width, bottom=y,
# -> 2463                            align=align, **kwargs)
# ...

# %% [markdown]
# ### histograms

# %%
marks=[50,60,70,50,50,30,50,70,50]
plt.figure()
plt.hist(marks)
# Out:
# (array([1., 0., 0., 0., 0., 5., 0., 1., 0., 2.]),
#  array([30., 34., 38., 42., 46., 50., 54., 58., 62., 66., 70.]),
#  <a list of 10 Patch objects>)

# %%
hieght_men_at_20=[4,5,4.5,5,6,7]

# %%
plt.figure()
_=plt.boxplot(hieght_men_at_20,whis='range')

# %% [markdown]
# ## Animations

# %%
import matplotlib.animation as animation
n=100
x=np.random.randn(n)
x
# Out:
# array([ 0.73922586,  0.41644118, -0.14137026, -0.27399614, -0.3798269 ,
#        -0.24168871, -0.97642699, -0.72762754, -0.64124508,  0.71772942,
#        -0.82285893,  1.87268436, -0.07628617,  1.41088863, -0.38852148,
#         1.59143891,  0.21461443, -0.61637244, -1.4826752 ,  0.38305487,
#         0.10758635, -0.86005329, -0.08960964,  1.3244235 ,  0.73016531,
#         0.13868293,  0.99191269, -0.14674717, -0.95623289,  0.97268847,
#         0.84660341, -0.69180436,  0.55179491,  0.93253828,  0.19205419,
#        -1.5725204 , -1.07813939, -0.11333946,  0.96358289, -1.44747067,
#        -0.61825219, -0.79046675,  1.22837999, -1.41717918,  0.45610261,
#         0.54493728,  1.11394771, -0.16115842,  0.11506026,  0.88745223,
#         1.31959454,  0.69410257, -1.38598574,  0.10708455,  0.59063273,
#         0.13660596,  0.08702843,  0.91438948,  0.27244078, -1.01707535,
#        -1.30069595, -0.08698086, -0.27724177, -0.69411381, -0.42759981,
# ...

# %%
def update(curr):
    if curr==n:
        a.event_source.stop()
    plt.cla()
    bins=np.arange(-4,4,0.5)
    plt.hist(x[:curr],bins=bins)
    plt.axis([-4,4,0,30])
    plt.gca().set_title('Sampling the Normal Distribution')
    plt.gca().set_ylabel('Frequency')
    plt.gca().set_xlabel('Value')
    plt.annotate('n={}'.format(curr),[3,27])

# %%
fig=plt.figure()
a=animation.FuncAnimation(fig,update,interval=100)

# %% [markdown]
# ## INTERACTIVITY

# %%
plt.figure()
data=np.random.rand(10)
plt.plot(data)
def onclick(event):
    plt.cla()
    plt.plot(data)
    plt.gca().set_title(
        'Event at pixes {},{} \nand data{},{}'.format(event.x,event.y.event.xdata.event.ydata))
plt.gcf().canvas.mpl_connect('button_press_event',onclick)
# Out:
# 4
